# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv

# %%
df = pd.read_csv("train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
df_test = pd.DataFrame()

# %%
df[["Name", "Age", "Sex"]]
# Out:
#                                                   Name   Age     Sex
# 0                              Braund, Mr. Owen Harris  22.0    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                               Heikkinen, Miss. Laina  26.0  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 4                             Allen, Mr. William Henry  35.0    male
# ..                                                 ...   ...     ...
# 886                              Montvila, Rev. Juozas  27.0    male
# 887                       Graham, Miss. Margaret Edith  19.0  female
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN  female
# 889                              Behr, Mr. Karl Howell  26.0    male
# 890                                Dooley, Mr. Patrick  32.0    male
#
# [891 rows x 3 columns]

# %% [markdown]
# Mediana wieku

# %%
df["Age"].median()
# Out:
# 28.0

# %% [markdown]
# Zamiana female na 0 i male na 1

# %%
df["Sex"]= [wiersz.replace("female", "0") for wiersz in df["Sex"]]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
df["Sex"]= [wiersz.replace("male", "1") for wiersz in df["Sex"]]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
df["Sex"] = df["Sex"].replace(["female", "male"], ["1", "0"])

# %%
df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %% [markdown]
# Rok urodzenia

# %%
df["Date of birth"] = 1912 - df["Age"]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  ... Cabin Embarked  Date of birth
# 0              1         0       3  ...   NaN        S         1890.0
# 1              2         1       1  ...   C85        C         1874.0
# 2              3         1       3  ...   NaN        S         1886.0
# 3              4         1       1  ...  C123        S         1877.0
# 4              5         0       3  ...   NaN        S         1877.0
# ..           ...       ...     ...  ...   ...      ...            ...
# 886          887         0       2  ...   NaN        S         1885.0
# 887          888         1       1  ...   B42        S         1893.0
# 888          889         0       3  ...   NaN        S            NaN
# 889          890         1       1  ...  C148        C         1886.0
# 890          891         0       3  ...   NaN        Q         1880.0
#
# [891 rows x 13 columns]

# %% [markdown]
# Liczba kobiet i mężczyzn

# %%
df["Sex"] = pd.to_numeric(df["Sex"])

# %%
liczba_mezczyzn = df["Sex"].sum()
print(liczba_mezczyzn)
# Out:
# 577

# %%
liczba_pasazerow = len(df["Sex"])
print(liczba_pasazerow)
# Out:
# 891

# %%
liczba_kobiet = liczba_pasazerow - liczba_mezczyzn 
print(liczba_kobiet)
# Out:
# 314
