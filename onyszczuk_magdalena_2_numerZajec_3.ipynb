# %%
#zadanie 1
imie = input("Podaj swoje imię: ")
print("-----------")
print(imie)
if imie.isalpha() == True:
  print(imie)
else:
  print("Błędne dane.")

# %%
nazwisko = input("Podaj swoje nazwisko: ")
print("-----------")
print(nazwisko)
if wiek.isalpha() == True:
  print(nazwisko)
else:
  print("Błędne dane.")

# %%
wiek = input("Ile masz lat? ")
print("-----------")
if wiek.isdigit() == True:
  wiek_int = int(wiek)
  print(wiek_int)
else:
  print("Podaj liczbę")

# %%
hasło = input("Podaj hasło: ")
print("-----------")
hasło2 = input("Powtórz hasło: ")
if hasło == hasło2:
  print("Poprawne zalogowanie.")
else:
  print("Nieprawidłowe hasło,")

# %%
numer_tel = input("Podaj numer telefonu.")

if numer_tel.isdigit and len(numer_tel) == 9:
  print(numer_tel)
else:
  print("Błędny numer. Proszę nie używać spacji i znaków specjalnych.")

# %% [markdown]
# Kalkulator

# %%
x = input("Podaj pierwszą liczbę: ")
if x.isdigit() == True:
  x_int = int(x)
  print(x_int)
else:
  print("błąd")
  x = input("Podaj pierwszą liczbę: ")
print("--------")


y = input("Podaj drugą liczbę: ")
if y.isdigit() == True:
  y_int = int(y)
  print(y_int)
else:
  print("błąd")
  y = input("Podaj pierwszą liczbę: ")
print("--------")


print("+",",", "-",",", "*", ",", "/")
dzialanie =  input("Jakie działanie chcesz wykonać?")
if dzialanie == "+":
  print(x_int + y_int)
elif dzialanie == "-":
  print(x_int - y_int)
elif dzialanie == "*":
  print(x_int * y_int)
elif dzialanie == "/":
  print(x_int / y_int)
else:
  print("Wprowadź odpowiedzni symbol.")
