# %%
#2
zmienna = """Lorem ipsum dolor sit amet, consectetur adipiscing elit, 
sed do eiusmod tempor incididunt ut labore 
et dolore magna aliqua."""
print(zmienna)
# Out:
# Lorem ipsum dolor sit amet, consectetur adipiscing elit,
# sed do eiusmod tempor incididunt ut labore
# et dolore magna aliqua.

# %%
#3
x1 = 1
x2 = 1.3
x3 = "liczba"
x4 = True
print(x1,x2,x3,x4)
# Out:
# 1 1.3 liczba True

# %%
#4
x = 2
y = 5
x + y
# Out:
# 7

# %%
x = 2
y = 5
x - y
# Out:
# -3

# %%
x = 2
y = 5
x * y
# Out:
# 10

# %%
x = 2
y = 5
x / y
# Out:
# 0.4

# %%
x = 2
y = 5
x % y
# Out:
# 2

# %%
x = 2
y = 5
x ** y
# Out:
# 32

# %%
#5
x = 3
y = 1.2
x1 = True
x2 = False
x > y
# Out:
# True

# %%
x = 3
y = 1.2
x1 = True
x2 = False
x < y
# Out:
# False

# %%
x = 3
y = 1.2
x1 = True
x2 = False
x == y
# Out:
# False

# %%
x = 3
y = 1.2
x1 = True
x2 = False
x != y
# Out:
# True

# %%
x = 3
y = 1.2
x1 = True
x2 = False
x >= y
# Out:
# True

# %%
x = 3
y = 1.2
x1 = True
x2 = False
x <= y
# Out:
# False

# %%
#6
x1 = "Niebieski kwiat i kolce"
x2 = "To naprawdę ładny głaz"
print("<-",x1,"|",x2,"->")
# Out:
# <- Niebieski kwiat i kolce | To naprawdę ładny głaz ->
